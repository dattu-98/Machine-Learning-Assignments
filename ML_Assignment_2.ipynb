# %% [markdown]
# **1. What is the concept of human learning? Please give two examples.**

# %% [markdown]
# Humans tend to learn by thinking about something, understanding the theory behind it and applying the knowledge to certain application.
# Learning can be defined as " any relatively permanent change in behaviour that occurs as a result of practice and experience".
#
# There are different types like Classical Conditioning, Operant Conditioning, Observational learning.
#
# Examples such as differentiating b/w Animals,People, Places. Learning new things, developing a new hobby etc..

# %% [markdown]
# **2. What different forms of human learning are there? Are there any machine learning equivalents?**

# %% [markdown]
# There are different types like Classical Conditioning, Operant Conditioning, Observational learning.
#
# * Supervised learning is similar to concept learning.
# * Artificial neural networks follow the neuronal principle of Hebbian learning, where the algorithm centres on inputs with similar properties, just like how neurons that activate simultaneously strengthen the synaptic link between each other

# %% [markdown]
# **3.What is machine learning, and how does it work? What are the key responsibilities of machine learning?**

# %% [markdown]
# Machine learning is a subset of artificial intelligence (AI). Interlinking of concepts of computer science, Mathematics, Domain Knowledge. This focuses on the use of data and algorithms to imitate the way that humans learn, gradually improving its accuracy.
#
# ML Responsibilities are:
# * Perform Statistical Analysis.
# * FIne Tuning of test results
# * Train and retrain systems.
# * Working on frameworks
# * Undertaking machine learning experiments and test
# * Design of ML programs
# * Finally implementing suitable AI/ML Algorithms

# %% [markdown]
# **4. Define the terms "penalty" and "reward" in the context of reinforcement learning.**

# %% [markdown]
# The reinforcement learning algorithm may be referred to an agent learns with environment. The agent receives rewards by performing correctly and get penalties if it is incorrect.

# %% [markdown]
# **5. Explain the term "learning as a search"?**

# %% [markdown]
# Learning can be viewed as a search through the space of all sentences in a concept description language for a sentence that best describes the data.
#
# Alternatively, it can be viewed as a search through all hypotheses in a hypothesis space. In either case, a generality relation usually determines the structure of the search space.

# %% [markdown]
# **6. What are the various goals of machine learning? What is the relationship between these and human learning?**

# %% [markdown]
# Develop and analyze models to understand:
# * What kind of tasks we can hope to learn & from what kind of data.
# * Discover patterns in our data and then make predictions based on often complex patterns to answer business questions.

# %% [markdown]
# **7. Illustrate the various elements of machine learning using a real-life illustration.**

# %% [markdown]
# * Image recognition
# * Speech recognition
# * Text to Speech conversion
# * Medical Diagnosis
# * Predictive Analytics
# * Autonomous Vehicles

# %% [markdown]
# **8. Provide an example of the abstraction method.**

# %% [markdown]
# * Abstraction is the technique of hiding implementation by providing a layer over the functionality
# * In Data science, if you do 'too much abstraction', you are also abstracting away the intuition of how the algorithm works and most importantly you are hiding away the knobs and levers necessary to tweak the model.
# * In logistic regression in scikit-learn L2 regularization

# %% [markdown]
# **9. What is the concept of generalization? What function does it play in the machine learning process?**

# %% [markdown]
# Generalization refers to your model's ability to adapt properly to new, previously unseen data, drawn from the same distribution as the one used to create the model.

# %% [markdown]
# **10.What is classification, exactly? What are the main distinctions between classification and regression?**

# %% [markdown]
# Classification is a process of categorizing a given set of data into classes, It can be performed on both structured or unstructured data. The process starts with predicting the class of given data points. The classes are often referred to as target, label or categories.
# * Ex: Gender classification, Yes or No, True or False, etc...
#
# Classification is done for discrete values and
# Regression is done for Continous values.Algorithms like Decision Tree, Random Forest, Linear Regression etc... are used

# %% [markdown]
# **11. What is regression, and how does it work? Give an example of a real-world problem that was solved using regression.**

# %% [markdown]
# * Regression in machine learning consists of mathematical methods that allow data scientists to predict a continuous outcome (y) based on the value of one or more predictor variables (x). Linear regression is probably the most popular form of regression analysis because of its ease-of-use in predicting and forecasting.
# * Prediction of Demand over Time
# * Prediction of Stock Price over Time
# * Prediction of Population over Time

# %% [markdown]
# **12. Describe the clustering mechanism in detail.**

# %% [markdown]
# * Cluster analysis, or clustering, is an unsupervised machine learning task.
# * It involves automatically discovering natural grouping in data. Unlike supervised learning (like predictive modeling), clustering algorithms only interpret the input data and find natural groups or clusters in feature space.
# * ALgorithms used are K-Means Clustering Algorithm, DBSCAN, Affinity Propagation

# %% [markdown]
# **13. Make brief observations on two of the following topics:
# i. Machine learning algorithms are used
# ii. Studying under supervision
# iii. Studying without supervision
# iv. Reinforcement learning is a form of learning based on positive reinforcement.**

# %% [markdown]
# * Machine learning algorithms are used:
# 1. Linear Regression
# 2. Logistic Regression
# 3. Naive Bayes
# 4. KNN
# 5. K-Means
# 6. Random Forest
# 7. SVM
# 8. Gradient Boosting Algorithms

# %% [markdown]
# * Studying under supervision:
# This means the data is labelled and then data is fed to algorithm. This is Supervised Machine Learning. Classification & Regression algorithms are used.

# %% [markdown]
# * Studying without supervision: This means data is not labelled directly fed into algorithm. This is called as unsupervised Machine Learning. Algorithms used are Clustering and Association

# %% [markdown]
# * **Reinforcement learning is a form of learning based on positive reinforcement.**
# 1. Reinforcement learning is all about making decisions sequentially. In simple words we can say that the output depends on the state of the current input and the next input depends on the output of the previous input
# 2. Positive Reinforcement is defined as when an event, occurs due to a particular behavior, increases the strength and the frequency of the behavior. In other words, it has a positive effect on behavior.
