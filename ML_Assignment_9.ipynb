# %% [markdown]
# **1. What is feature engineering, and how does it work? Explain the various aspects of feature engineering in depth.**

# %% [markdown]
# Feature engineering is the process of selecting, manipulating, and transforming raw data into features that can be used in supervised learning.  in simple terms, is the act of converting raw observations into desired features using statistical or machine learning approaches.
#
# Some of the feature engineering techniques are
# 1. Imputation
# 2. Handling outliers
# 3. Log Transformation
# 4. One hot encoding
# 5. Scaling

# %% [markdown]
# **2. What is feature selection, and how does it work? What is the aim of it? What are the various methods of function selection?**

# %% [markdown]
# Feature selection methods are intended to reduce the number of input variables to those that are believed to be most useful to a model in order to predict the target variable. So Feature selection is primarily focused on removing non-informative or redundant predictors from the model.
#
# There are different methods in Feature selection. Wrapper, Filter, Hybrid
#
# ![](https://www.researchgate.net/profile/Durai-Vincent-P-M/publication/344212522/figure/fig1/AS:934800038842368@1599885105607/Overview-of-feature-selection-methods-for-machine-learning-algorithms.jpg)

# %% [markdown]
# **3. Describe the function selection filter and wrapper approaches. State the pros and cons of each approach?**

# %% [markdown]
# Filter selection: Filter methods are generally used as a preprocessing step. The selection of features is independent of any machine learning algorithms. Instead, features are selected on the basis of their scores in various statistical tests for their correlation with the outcome variable.
#
# ![](https://www.analyticsvidhya.com/wp-content/uploads/2016/11/FS1.png)
#
# One of the disadvantage is Filter method remove Multicollinearity so we must deal with multicollinearity before training models
#
# Wrapper Selection: n wrapper methods, we try to use a subset of features and train a model using them. Based on the inferences that we draw from the previous model, we decide to add or remove features from your subset. The problem is essentially reduced to a search problem.
#
# ![](https://www.analyticsvidhya.com/wp-content/uploads/2016/11/Wrapper_1-1024x287.png)
#
# Few examples are Forward selection, Backward selection, Recursive Feature selection.

# %% [markdown]
# **4.
# i. Describe the overall feature selection process.
# ii. Explain the key underlying principle of feature extraction using an example. What are the most widely used function extraction algorithms?**

# %% [markdown]
# Feature selection can be defined as selecting the required features in the dataset which suits in the Machine Learning algorithm. Feature selection helps by reducing overfitting, improving accuracy, reducing the training time.
#
# Feature Extraction: Feature Extraction aims to reduce the number of features in a dataset by creating new features from the existing ones and then discarding the original features. These new reduced set of features should then be able to summarize most of the information contained in the original set of features. In this way, a summarised version of the original features can be created from a combination of the original set.
#
# Feature Extraction improves the accuracy, speeds up training, reducing overfitting.
#
# PCA, ICA, LDA, LLE, t-SNE,AE are the techniques used for feature extraction.
# Principal Component analysis is the most used dimensionality reduction technique. This maximizes variance and minimizes reconstruction error.

# %%
import pandas as pd

# %%
df=pd.read_csv("F:\Data Science\Data Analysis\Data Set_Tableau\Data Set\CarMakers.csv")

# %%
df
# Out:
#      Car ID         make fuel-type aspiration num-of-doors   body-style  \
# 0         1  alfa-romero       gas        std          two  convertible
# 1         2  alfa-romero       gas        std          two  convertible
# 2         3  alfa-romero       gas        std          two    hatchback
# 3         4         audi       gas        std         four        sedan
# 4         5         audi       gas        std         four        sedan
# ..      ...          ...       ...        ...          ...          ...
# 190     191        volvo       gas        std         four        sedan
# 191     192        volvo       gas      turbo         four        sedan
# 192     193        volvo       gas        std         four        sedan
# 193     194        volvo    diesel      turbo         four        sedan
# 194     195        volvo       gas      turbo         four        sedan
#
#     drive-wheels engine-location  wheel-base  length  ...  num-of-cylinders  \
# ...

# %%
df=df.drop(columns=['Car ID'])

# %%
df
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 190        volvo       gas        std         four        sedan          rwd
# 191        volvo       gas      turbo         four        sedan          rwd
# 192        volvo       gas        std         four        sedan          rwd
# 193        volvo    diesel      turbo         four        sedan          rwd
# 194        volvo       gas      turbo         four        sedan          rwd
#
# ...

# %%
df.describe()
# Out:
#        wheel-base      length       width      height  curb-weight  \
# count  195.000000  195.000000  195.000000  195.000000   195.000000
# mean    98.896410  174.256923   65.886154   53.861538  2559.000000
# std      6.132038   12.476443    2.132484    2.396778   524.715799
# min     86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%     94.500000  166.300000   64.050000   52.000000  2145.000000
# 50%     97.000000  173.200000   65.400000   54.100000  2414.000000
# 75%    102.400000  184.050000   66.900000   55.650000  2943.500000
# max    120.900000  208.100000   72.000000   59.800000  4066.000000
#
#        engine-size        bore      stroke  compression-ratio  horsepower  \
# count   195.000000  195.000000  195.000000         195.000000  195.000000
# mean    127.938462    3.329385    3.250308          10.194974  103.271795
# std      41.433916    0.271866    0.314115           4.062109   37.869730
# ...

# %%
df.columns
# Out:
# Index(['make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style',
#        'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width',
#        'height', 'curb-weight', 'num-of-cylinders', 'engine-size', 'bore',
#        'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df1=df[['wheel-base','length','width','height','curb-weight','engine-size','bore','stroke','compression-ratio','horsepower','peak-rpm','city-mpg','highway-mpg']]

# %%
df1
# Out:
#      wheel-base  length  width  height  curb-weight  engine-size  bore  \
# 0          88.6   168.8   64.1    48.8         2548          130  3.47
# 1          88.6   168.8   64.1    48.8         2548          130  3.47
# 2          94.5   171.2   65.5    52.4         2823          152  2.68
# 3          99.8   176.6   66.2    54.3         2337          109  3.19
# 4          99.4   176.6   66.4    54.3         2824          136  3.19
# ..          ...     ...    ...     ...          ...          ...   ...
# 190       109.1   188.8   68.9    55.5         2952          141  3.78
# 191       109.1   188.8   68.8    55.5         3049          141  3.78
# 192       109.1   188.8   68.9    55.5         3012          173  3.58
# 193       109.1   188.8   68.9    55.5         3217          145  3.01
# 194       109.1   188.8   68.9    55.5         3062          141  3.78
#
#      stroke  compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg
# ...

# %%
df1.describe()
# Out:
#        wheel-base      length       width      height  curb-weight  \
# count  195.000000  195.000000  195.000000  195.000000   195.000000
# mean    98.896410  174.256923   65.886154   53.861538  2559.000000
# std      6.132038   12.476443    2.132484    2.396778   524.715799
# min     86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%     94.500000  166.300000   64.050000   52.000000  2145.000000
# 50%     97.000000  173.200000   65.400000   54.100000  2414.000000
# 75%    102.400000  184.050000   66.900000   55.650000  2943.500000
# max    120.900000  208.100000   72.000000   59.800000  4066.000000
#
#        engine-size        bore      stroke  compression-ratio  horsepower  \
# count   195.000000  195.000000  195.000000         195.000000  195.000000
# mean    127.938462    3.329385    3.250308          10.194974  103.271795
# std      41.433916    0.271866    0.314115           4.062109   37.869730
# ...

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
scaled_data=scalar.fit_transform(df1)

# %%
df1_scaled=pd.DataFrame(scaled_data,columns=df1.columns)

# %%
df1_scaled
# Out:
#      wheel-base    length     width    height  curb-weight  engine-size  \
# 0     -1.683439 -0.438504 -0.839749 -2.117245    -0.021018     0.049883
# 1     -1.683439 -0.438504 -0.839749 -2.117245    -0.021018     0.049883
# 2     -0.718803 -0.245646 -0.181548 -0.611363     0.504425     0.582216
# 3      0.147735  0.188283  0.147553  0.183409    -0.424175    -0.458253
# 4      0.082336  0.188283  0.241582  0.183409     0.506335     0.195065
# ..          ...       ...       ...       ...          ...          ...
# 190    1.668263  1.168643  1.416941  0.685370     0.750905     0.316049
# 191    1.668263  1.168643  1.369927  0.685370     0.936243     0.316049
# 192    1.668263  1.168643  1.416941  0.685370     0.865547     1.090351
# 193    1.668263  1.168643  1.416941  0.685370     1.257240     0.412837
# 194    1.668263  1.168643  1.416941  0.685370     0.961082     0.316049
#
#          bore    stroke  compression-ratio  horsepower  peak-rpm  city-mpg  \
# ...

# %%
df1_scaled.describe()
# Out:
#          wheel-base        length         width        height   curb-weight  \
# count  1.950000e+02  1.950000e+02  1.950000e+02  1.950000e+02  1.950000e+02
# mean  -3.354582e-15  2.659980e-15  5.943963e-16  1.356180e-15 -6.547469e-17
# std    1.002574e+00  1.002574e+00  1.002574e+00  1.002574e+00  1.002574e+00
# min   -2.010434e+00 -2.664403e+00 -2.626295e+00 -2.535546e+00 -2.046359e+00
# 25%   -7.188029e-01 -6.393973e-01 -8.632563e-01 -7.786830e-01 -7.910294e-01
# 50%   -3.100587e-01 -8.493154e-02 -2.285622e-01  9.974864e-02 -2.770514e-01
# 75%    5.728288e-01  7.869458e-01  4.766534e-01  7.481148e-01  7.346638e-01
# max    3.597536e+00  2.719540e+00  2.874387e+00  2.484063e+00  2.879424e+00
#
#         engine-size          bore        stroke  compression-ratio  \
# count  1.950000e+02  1.950000e+02  1.950000e+02       1.950000e+02
# mean   5.778853e-17  1.588473e-15  1.266224e-15       1.503071e-16
# std    1.002574e+00  1.002574e+00  1.002574e+00       1.002574e+00
# ...

# %%
from sklearn.decomposition import PCA
pca=PCA()
df_pca=pca.fit_transform(df1_scaled)

# %%
pca_df1=pd.DataFrame(df_pca,columns=df1_scaled.columns)
pca_df1
# Out:
#      wheel-base    length     width    height  curb-weight  engine-size  \
# 0     -0.685875 -2.139268  0.385264  2.424392     0.488477     0.272523
# 1     -0.685875 -2.139268  0.385264  2.424392     0.488477     0.272523
# 2      0.303235 -1.335230 -1.450409 -0.604932     0.178596     2.014891
# 3     -0.216287 -0.247787 -0.088081 -1.176435     0.185431    -0.101747
# 4      1.157449 -1.178485 -0.078932 -1.201137    -0.060344     0.323002
# ..          ...       ...       ...       ...          ...          ...
# 190    2.606889  0.352591  1.000892 -0.465061     0.273011    -0.919540
# 191    3.402368 -0.313175  0.934782 -0.320664     0.180908    -0.781424
# 192    3.294897 -0.547480  1.450941 -0.440986     0.853471     0.053156
# 193    2.084583  2.999497 -0.999036 -0.737290     1.960679     0.922066
# 194    3.037436  0.079169  1.075584 -0.530367     0.193879    -0.838094
#
#          bore    stroke  compression-ratio  horsepower  peak-rpm  city-mpg  \
# ...

# %%
pca.explained_variance_ratio_
# Out:
# array([0.52275385, 0.17445603, 0.09208097, 0.06932579, 0.04166607,
#        0.03163315, 0.02283684, 0.01813008, 0.00907718, 0.00735305,
#        0.00511121, 0.00401923, 0.00155656])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("No of columns")
plt.ylabel("EVR")
plt.show()

# %% [markdown]
# **5. Describe the feature engineering process in the sense of a text categorization issue.**

# %% [markdown]
# Feature engineering is the process of selecting, manipulating, and transforming raw data into features that can be used in Machine Learning models. So this is the act of converting raw observations into desired features using statistical or machine learning approaches. Feature Engineering in the domain of Text categorization increases the accuracy. Tasks like finding Number of Characters, Number of words, Number of capital characters, Number of capital words, Count the number of punctuations, Number of words in quotes, Number of sentences, Count the number of unique words,  Count of hashtags etc......
#
# Libraries used in the field of text categorization are spacy, nltk, textblob etc...

# %% [markdown]
# **6. What makes cosine similarity a good metric for text categorization? A document-term matrix has two rows with values of (2, 3, 2, 0, 2, 3, 3, 0, 1) and (2, 1, 0, 0, 3, 2, 1, 3, 1). Find the resemblance in cosine.**

# %% [markdown]
# Cosine similarity is one of the metric to measure the text-similarity between two documents irrespective of their size in Natural language Processing. A word is represented into a vector form. The text documents are represented in n-dimensional vector space.
#
# ![](https://studymachinelearning.com/wp-content/uploads/2019/09/Cosine-similarity-Wikipedia.png)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
import numpy as np

# %%
mat=np.array([[2, 3, 2, 0, 2, 3, 3, 0, 1],[2, 1, 0, 0, 3, 2, 1, 3, 1]])

# %%
mat
# Out:
# array([[2, 3, 2, 0, 2, 3, 3, 0, 1],
#        [2, 1, 0, 0, 3, 2, 1, 3, 1]])

# %%
cosine_similarity(mat)
# Out:
# array([[1.        , 0.67530325],
#        [0.67530325, 1.        ]])

# %% [markdown]
# **7.
# i. What is the formula for calculating Hamming distance? Between 10001011 and 11001111, calculate the Hamming gap.
# ii. Compare the Jaccard index and similarity matching coefficient of two features with values (1, 1, 0, 0, 1, 0, 1, 1) and (1, 1, 0, 0, 0, 1, 1, 1), respectively (1, 0, 0, 1, 1, 0, 0, 1).**

# %% [markdown]
# Hamming distance is a metric for comparing two binary data strings. Where the Hamming distance between two strings of equal length is the number of positions at which the corresponding character is different.
#
# 10001011 and 11001111
# Hamming gap : 2
#
# Jaccard index: The Jaccard Index, also known as the Jaccard similarity coefficient, is a statistic used in understanding the similarities between sample sets.
#
# ![](https://images.deepai.org/glossary-terms/jaccard-index-9707615.jpg)
#
# Similarity matching coefficient:
#
# ![](https://miro.medium.com/max/674/1*TPZ0LAOTzuN6U863AegTKw.jpeg)

# %%
def jaccard_similarity(x,y):
    intersection = np.logical_and(x, y)
    union = np.logical_or(x, y)
    similarity = intersection.sum() / float(union.sum())
    return similarity

# %%
jaccard_similarity(A,B)
# Out:
# 0.6666666666666666

# %%
jaccard_similarity(B,C)
# Out:
# 0.2857142857142857

# %%
jaccard_similarity(C,A)
# Out:
# 0.5

# %%
A=[1, 1, 0, 0, 1, 0, 1, 1]
B=[1, 1, 0, 0, 0, 1, 1, 1]
C=[1, 0, 0, 1, 1, 0, 0, 1]

# %% [markdown]
# 1. SMC(AB)=(4+2)/(8)=0.75
# 2. SMC(BC)=(2+1)/(8)=0.375
# 3. SMC(CA)=(3+2)/(8)=0.625

# %% [markdown]
# **8. State what is meant by  "high-dimensional data set"? Could you offer a few real-life examples? What are the difficulties in using machine learning techniques on a data set with many dimensions? What can be done about it?**

# %% [markdown]
# High dimensional data refers to a dataset in which the Number of features p is larger than the Number of observations N, often written as p >> N.
#
# When the number of features in a dataset exceeds the number of observations, we will never have a deterministic answer. It becomes impossible to find a model that can describe the relationship between the predictor variables and the response variable because we don’t have enough observations to train the model on.
#
# Few real life examples are: Health care data, Financial Data, Genomics.
#
# We can handle high dimensionality feature data set by selecting significant features of dataset & dimensionality reduction methods like PCA, ICA, LDA etc...

# %% [markdown]
# **9. Make a few quick notes on:1. PCA is an acronym for Principal Component analysis. 2. Use of vectors 3. Embedded technique**

# %% [markdown]
# 1. Principal Component analysis: Principal component analysis (PCA) is a technique for reducing the dimensionality of such datasets, increasing interpretability but at the same time minimizing information loss. It does so by creating new uncorrelated variables that successively maximize variance.
#
# 2. Use of Vectors: A vector is a mathematical object that encodes a length and direction. Vectors are commonly used in machine learning as they lend a convenient way to organize data.  Often one of the very first steps in making a machine learning model is vectorizing the data. Support Vector Machines uses vectors and finds the hyperplane which helps in classification.
#
# 3. Embedded technique: Embedded techniques is used in Feature selection. Embedded methods combine the qualities’ of filter and wrapper methods. It’s implemented by algorithms that have their own built-in feature selection methods.
#
# ![](https://www.analyticsvidhya.com/wp-content/uploads/2016/11/Embedded_1.png)
#
# Lasso & Ridge Regularization are the most commonly used Embedded methods

# %% [markdown]
# **10. Make a comparison between:1. Sequential backward selection vs. sequential forward selection 2. Function selection methods: filter vs. wrapper 3. SMC vs. Jaccard coefficient**

# %% [markdown]
# 1. Sequential feature selection algorithms are basically part of the wrapper methods where it adds and removes features from the dataset sequentially. Sometimes it evaluates each feature separately and selects M features from N features on the basis of individual scores. This searching algorithm adds or removes the feature candidate from the candidate subset while evaluating the objective function or criterion. Sequential searches follow only one direction: either it increases the number of features in the subset or reduces the number of features in the candidate feature subset.
#
# > Sequential Forward Selection(SFS): In SFS variant features are sequentially added to an empty set of features until the addition of extra features does not reduce the criterion.
#
# > Sequential Backward Selection(SBS): This variant algorithm picks all the features from the input data and combines them in a set and sequentially removes them from the set until the removal of further features increases the criterion.
#
# 2.1) Filter Methods: This method is used during the feature selection operation. We perform feature selection at the time of preprocessing of the data. These methods select the features before using a machine learning algorithm on the given data. But the problem with the method is that it does not remove the multicollinearity from the data.
#
#     Techniques used are:
#     1. Information gain.
#     2. Chi-square test.
#     3. Fisher’s Score.
#     4. Correlation coefficient.
#     5. Variance threshold
#     6. Mean absolute deviation.
#     7. dispersion coefficient
#
# 2.2) Wrapper Methods: In this method, feature selection algorithms try to train the model with a reduced number of subsets of features in an iterative way. In this method, the algorithm pushes a set of features iteratively in the model and in iteration the number of features gets reduced or increased.
#
#     Techniques used are:
#     1. Foreword selection.
#     2. Backward selection.
#     3. Bi-directional selection.
#     4. Exhaustive selection.
#     5. Recursive selection.
#
# 3.1) Jaccard Coefficient: The Jaccard Index, also known as the Jaccard similarity coefficient, is a statistic used in understanding the similarities between sample sets.
#
# ![](https://images.deepai.org/glossary-terms/jaccard-index-9707615.jpg)
#
# Similarity Matching Coefficient:
# The simple matching coefficient (SMC) or Rand similarity coefficient is a statistic used for comparing the similarity and diversity of sample sets.
# ![](https://miro.medium.com/max/674/1*TPZ0LAOTzuN6U863AegTKw.jpeg)
